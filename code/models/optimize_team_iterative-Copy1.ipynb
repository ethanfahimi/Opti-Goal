# %% [markdown]
# # Load Packages and Data

# %%
using CSV, DataFrames, JuMP, Gurobi;

# %% [markdown]
# # Model Solver

# %%
function solve_fantasy_football_model(; 
        initial_squad::Vector{Int64},
        weeks::UnitRange{Int64}, 
        triple_captains_remaining::Float64, 
        bench_boost_remaining::Float64, 
        wildcard_remaining::Float64, 
        freehit_remaining::Float64
    )

    # initialize model
    model = Model(Gurobi.Optimizer);
    
    # players in squad
    @variable(model, S[players, weeks], Bin)
    
    # players in team
    @variable(model, X[players, weeks], Bin)
    
    # captain and triple captain
    @variable(model, C[players, weeks], Bin)
    @variable(model, TC[players, weeks], Bin)
    
    # bench boost
    @variable(model, BB[weeks], Bin)
    
    # transfer tracker
    @variable(model, Tr[players, weeks] >= 0, Bin)
    @variable(model, TTr[weeks] >= 0, Int)
    transfer_weeks = (minimum(weeks) + 1) : maximum(weeks)
    
    # carry forward transfers
    @variable(model, CarryForwardTransfers[weeks] >= 0, Int)
    
    # wildcard
    @variable(model, WC[weeks], Bin)
    
    # free hit
    @variable(model, FH[weeks], Bin)
    
    # objective function
    @objective(
        model, 
        Max, 
        sum(sum(X[i, j] * XP[i, j] for i in players) for j in weeks)
        +
        sum(sum(C[i, j] * XP[i, j] for i in players) for j in weeks)
        +
        sum(sum(TC[i, j] * XP[i, j] for i in players) for j in weeks)
        +
        sum(sum((S[i, j] - X[i, j]) * BB[j] * XP[i, j] for i in players) for j in weeks) 
        -
        4 * sum(TTr[j] * (1 - WC[j] - FH[j]) for j in transfer_weeks)
    )

    # starting squad from prior iteration
    if sum(initial_squad) > 0
        for i in initial_squad
            @constraint(model, S[i, 1] == 1)
        end
    end
 
    # salary cap
    @constraint(model, [j in weeks], sum(P[i] * S[i, j] for i in players) <= 100)
    
    # number of players in squad
    @constraint(model, [j in weeks], sum(GK[i] * S[i, j] for i in players) == 2)
    @constraint(model, [j in weeks], sum(DEF[i] * S[i, j] for i in players) == 5)
    @constraint(model, [j in weeks], sum(MID[i] * S[i, j] for i in players) == 5)
    @constraint(model, [j in weeks], sum(FWD[i] * S[i, j] for i in players) == 3)
    
    # number of players in team
    @constraint(model, [j in weeks], sum(X[i, j] for i in players) == 11)
    @constraint(model, [j in weeks], sum(GK[i] * X[i, j] for i in players) == 1)
    @constraint(model, [j in weeks], sum(DEF[i] * X[i, j] for i in players) >= 3)
    @constraint(model, [j in weeks], sum(MID[i] * X[i, j] for i in players) >= 2)
    @constraint(model, [j in weeks], sum(FWD[i] * X[i, j] for i in players) >= 1)
    
    # players in team must be in squad
    @constraint(model, [j in weeks, i in players], X[i, j] <= S[i, j])
    
    # number of players from each team
    @constraint(model, [j in weeks], sum(ARS[i] * S[i, j] for i in players) <= 3)
    @constraint(model, [j in weeks], sum(CHE[i] * S[i, j] for i in players) <= 3)
    @constraint(model, [j in weeks], sum(LIV[i] * S[i, j] for i in players) <= 3)
    @constraint(model, [j in weeks], sum(MCI[i] * S[i, j] for i in players) <= 3)
    @constraint(model, [j in weeks], sum(MUN[i] * S[i, j] for i in players) <= 3)
    @constraint(model, [j in weeks], sum(TOT[i] * S[i, j] for i in players) <= 3)
    
    # one captain per week
    @constraint(model, [j in weeks], sum(C[i, j] for i in players) == 1)
    @constraint(model, [j in weeks, i in players], C[i, j] <= X[i, j])
    
    # one triple captain in season
    @constraint(model, sum(sum(TC[i, j] for i in players) for j in weeks) == triple_captains_remaining)
    @constraint(model, [j in weeks, i in players], TC[i, j] <= C[i, j])
    
    # one bench boost in season
    @constraint(model, sum(BB[j] for j in weeks) == bench_boost_remaining)
    
    # track transfers
    @constraint(model, [j in transfer_weeks, i in players], Tr[i, j] >= S[i, j] - S[i, j-1])
    @constraint(model, [j in transfer_weeks], TTr[j] == sum(Tr[i, j] for i in players) - 1 - CarryForwardTransfers[j])
    
    # carry forward transfers
    @constraint(model, CarryForwardTransfers[1] == 0)
    @constraint(model, [j in 2:maximum(weeks)], CarryForwardTransfers[j] <= 1)
    @constraint(model, [j in 2:maximum(weeks)], CarryForwardTransfers[j] >= 0)
    @constraint(model, [j in 2:maximum(weeks)], CarryForwardTransfers[j] <= CarryForwardTransfers[j-1] + 1 - TTr[j])
    
    # wildcards
    @constraint(model, sum(WC[j] for j in weeks) == wildcard_remaining)
    @constraint(model, [j in 2:maximum(weeks)], WC[j] + WC[j-1] <= 1)
    
    # free hit
    @constraint(model, sum(FH[j] for j in weeks) == freehit_remaining)
    @constraint(model, FH[1] == 0)
    @constraint(model, [j in 2:(maximum(weeks)-1), i in players], S[i, j+1] - S[i, j-1] <= 1 - FH[j])
    @constraint(model, [j in weeks], FH[j] + WC[j] <= 1)
    
    # solve model
    optimize!(model)
    objective_value(model)

    # create list of decision variables
    decision_variables = Dict(
        "S" => value.(S),
        "X" => value.(X),
        "C" => value.(C),
        "TC" => value.(TC),
        "BB" => value.(BB),
        "Tr" => value.(Tr),
        "TTr" => value.(TTr),
        "CarryForwardTransfers" => value.(CarryForwardTransfers),
        "WC" => value.(WC),
        "FH" => value.(FH)
    )

    return decision_variables
end;

# %% [markdown]
# # Model Parameters

# %%
# load data sets
team = CSV.read("../../data/processed/team.csv", DataFrame)
pos = CSV.read("../../data/processed/position.csv", DataFrame)
price = CSV.read("../../data/processed/price.csv", DataFrame)

# define players
players = 1:nrow(team)

# player positions
GK = pos.PosGK
DEF = pos.PosDEF
MID = pos.PosMID
FWD = pos.PosFWD

# define teams
ARS = team.TeamARS
CHE = team.TeamCHE
LIV = team.TeamLIV
MCI = team.TeamMCI
MUN = team.TeamMUN
TOT = team.TeamTOT

# define prices
P = price.Price;

# %% [markdown]
# # Initial Solution

# %% [markdown]
# ### Fit Model

# %%
# extract expected points
points = CSV.read("../../data/processed/points.csv", DataFrame);
XP = points[:, 2:end];

# fit model
decision_variables = solve_fantasy_football_model(
    initial_squad = [0],
    weeks = 1:19, 
    triple_captains_remaining = 1.0, 
    bench_boost_remaining = 1.0, 
    wildcard_remaining = 2.0, 
    freehit_remaining = 1.0
);
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-09
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-
26
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.174509340000e+03, best bound 1.174509340000e+03, gap 0.0000%
#
# User-callback calls 95562, time in user-callback 0.06 sec

# %% [markdown]
# ### Extract Fitted Team

# %%
function is_nonzero_row(row)
    return sum(row[2:end]) > 0.0000001
end

function identify_team(decision_variables, n)
    optimal_team = hcat(team.Name[players], decision_variables["X"][:, n])
    optimal_team = filter(row -> is_nonzero_row(row), DataFrame(optimal_team, :auto))
    rename!(optimal_team, :x2 => :Team)
    rename!(optimal_team, :x1 => :Player)
end

function identify_squad(decision_variables, n)
    optimal_squad = hcat(team.Name[players], decision_variables["S"][:, n])
    optimal_squad = filter(row -> is_nonzero_row(row), DataFrame(optimal_squad, :auto))
    rename!(optimal_squad, :x2 => :Squad)
    rename!(optimal_squad, :x1 => :Player)
end;

function identify_captain(decision_variables, n)
    optimal_captain = hcat(team.Name[players], decision_variables["C"][:, n])
    optimal_captain = filter(row -> is_nonzero_row(row), DataFrame(optimal_captain, :auto))
    rename!(optimal_captain, :x2 => :Captain)
    rename!(optimal_captain, :x1 => :Player)
end

function identify_triple_captain(decision_variables, n)
    optimal_triple_captain = hcat(team.Name[players], decision_variables["TC"][:, n])
    optimal_triple_captain = filter(row -> is_nonzero_row(row), DataFrame(optimal_triple_captain, :auto))
    rename!(optimal_triple_captain, :x2 => :TripCaptain)
    rename!(optimal_triple_captain, :x1 => :Player)
end

function compile_results(decision_variables, n)
    
    df1 = identify_squad(decision_variables, n)
    df2 = identify_team(decision_variables, n)
    df3 = identify_captain(decision_variables, n)
    df4 = identify_triple_captain(decision_variables, n)
    
    result = outerjoin(df1, df2, on = :Player) |> x -> outerjoin(x, df3, on = :Player) |> x -> outerjoin(x, df4, on = :Player)
    result = coalesce.(result, 0)
    
    result.BB = fill(sum(decision_variables["BB"][n]), nrow(result))
    result.WC = fill(sum(decision_variables["WC"][n]), nrow(result))
    result.FH = fill(sum(decision_variables["FH"][n]), nrow(result))
    result.TTr = fill(sum(decision_variables["TTr"][n]), nrow(result))
    
    return(result)
end;

# %%
# compile results
for i in 1:38
    filename = "../../data/final/single_solution/week_$i.csv"
    df_to_write = compile_results(decision_variables, i)
    CSV.write(filename, df_to_write)
end;
# Out:
# KeyError: key 20 not found
#
# Stacktrace:
#  [1] getindex
#    @ C:\Users\Dilan\.julia\packages\JuMP\ptoff\src\Containers\DenseAxisArray.jl:120 [inlined]
#  [2] _getindex_recurse
#    @ C:\Users\Dilan\.julia\packages\JuMP\ptoff\src\Containers\DenseAxisArray.jl:355 [inlined]
#  [3] _getindex_recurse
#    @ C:\Users\Dilan\.julia\packages\JuMP\ptoff\src\Containers\DenseAxisArray.jl:354 [inlined]
#  [4] to_index(A::JuMP.Containers.DenseAxisArray{Float64, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Tuple{JuMP.Containers._AxisLookup{Tuple{Int64, Int64}}, JuMP.Containers._AxisLookup{Tuple{Int64, Int64}}}}, idx::Tuple{Colon, Int64})
#    @ JuMP.Containers C:\Users\Dilan\.julia\packages\JuMP\ptoff\src\Containers\DenseAxisArray.jl:364
#  [5] getindex(::JuMP.Containers.DenseAxisArray{Float64, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Tuple{JuMP.Containers._AxisLookup{Tuple{Int64, Int64}}, JuMP.Containers._AxisLookup{Tuple{Int64, Int64}}}}, ::Function, ::Vararg{Any}; kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#    @ JuMP.Containers C:\Users\Dilan\.julia\packages\JuMP\ptoff\src\Containers\DenseAxisArray.jl:391
#  [6] getindex(::JuMP.Containers.DenseAxisArray{Float64, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Tuple{JuMP.Containers._AxisLookup{Tuple{Int64, Int64}}, JuMP.Containers._AxisLookup{Tuple{Int64, Int64}}}}, ::Function, ::Int64)
#    @ JuMP.Containers C:\Users\Dilan\.julia\packages\JuMP\ptoff\src\Containers\DenseAxisArray.jl:384
#  [7] identify_squad(decision_variables::Dict{String, JuMP.Containers.DenseAxisArray{Float64, N} where N}, n::Int64)
#    @ Main .\In[16]:13
#  [8] compile_results(decision_variables::Dict{String, JuMP.Containers.DenseAxisArray{Float64, N} where N}, n::Int64)
#    @ Main .\In[16]:35
#  [9] top-level scope
#    @ .\In[17]:4

# %% [markdown]
# # Fit Iterative Models

# %%
# initialize chips
triple_captains_remaining = 1.0
bench_boost_remaining = 1.0
wildcard_remaining = 2.0 
freehit_remaining = 1.0
# Out:
# 1.0

# %% [markdown]
# ### Extract Starting Point

# %%
# identify squad
S = decision_variables["S"]
num_rows = size(S, 1)
squad = [i for i in 1:num_rows if value(S[i, 1]) == 1]
squad = convert(Array{Int}, squad)

# save starting squad
filename = "../../data/final/iterative_solution/week_1.csv"
df_to_write = compile_results(decision_variables, 1)
CSV.write(filename, df_to_write);

# %%
# identify chip usage
triple_captains_remaining -= sum(decision_variables["TC"][:, 1])
bench_boost_remaining -= sum(decision_variables["BB"][1])
wildcard_remaining -= sum(decision_variables["WC"][1])
freehit_remaining -= sum(decision_variables["FH"][1]);

# %%
for i in 2:38

    # extract expected points
    points = CSV.read("../../data/processed/predicted_points/without_injuries/points_$(i).csv", DataFrame);
    XP = points[:, 2:end];
    
    # fit model
    decision_variables_it = solve_fantasy_football_model(
        initial_squad = squad,
        weeks = 1:(11 - i), 
        triple_captains_remaining = triple_captains_remaining, 
        bench_boost_remaining = bench_boost_remaining, 
        wildcard_remaining = wildcard_remaining, 
        freehit_remaining = freehit_remaining
    );

    # compile weekly result
    filename = "../../data/final/iterative_solution/week_$i.csv"
    df_to_write = compile_results(decision_variables_it, 2)
    CSV.write(filename, df_to_write)

    filename = "../../data/final/iterative_solution/prev_week_$i.csv"
    df_to_write = compile_results(decision_variables_it, 1)
    CSV.write(filename, df_to_write)
    
    # identify squad
    S = decision_variables_it["S"]
    num_rows = size(S, 1)
    squad = [i for i in 1:num_rows if value(S[i, 2]) == 1]
    squad = convert(Array{Int}, squad)

    # identify chip usage
    triple_captains_remaining -= sum(decision_variables_it["TC"][:, 2])
    bench_boost_remaining -= sum(decision_variables_it["BB"][2])
    wildcard_remaining -= sum(decision_variables_it["WC"][2])
    freehit_remaining -= sum(decision_variables_it["FH"][2])
    
end;
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-09
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1185G7 @ 3.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4507 rows, 4635 columns and 16961 nonzeros
# Model fingerprint: 0x75b45686
# Model has 1840 quadratic objective terms
# Variable types: 0 continuous, 4635 integer (4617 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-02, 7e+00]
#   QObjective range [3e-02, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective 453.2765800
# Presolve removed 353 rows and 483 columns
# Presolve time: 0.05s
# Presolved: 5804 rows, 5802 columns, 20254 nonzeros
# Variable types: 0 continuous, 5802 integer (5780 binary)
#
# Root relaxation: objective 8.163322e+02, 7904 iterations, 0.77 seconds (0.70 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  816.33224    0 1687  453.27658  816.33224  80.1%     -    1s
# H    0     0                     523.0822400  816.33224  56.1%     -    1s
# H    0     0                     542.2312600  816.33224  50.6%     -    1s
# H    0     0                     545.8518100  816.33224  49.6%     -    1s
# H    0     0                     560.7455700  816.33224  45.6%     -    1s
#      0     0  681.59143    0 1358  560.74557  681.59143  21.6%     -    3s
# H    0     0                     562.1347400  681.59143  21.3%     -    3s
#      0     0  681.07217    0 1361  562.13474  681.07217  21.2%     -    3s
# H    0     0                     569.8541200  681.07217  19.5%     -    4s
# H    0     0                     570.1347100  681.07217  19.5%     -    4s
#      0     0  581.01646    0 1166  570.13471  581.01646  1.91%     -    4s
# H    0     0                     570.4734501  579.72503  1.62%     -    6s
# H    0     0                     572.5456300  579.72503  1.25%     -    6s
#      0     0  575.34421    0 1110  572.54563  575.34421  0.49%     -    6s
#      0     0  575.33830    0 1098  572.54563  575.33830  0.49%     -    6s
#      0     2  575.33830    0 1098  572.54563  575.33830  0.49%     -    6s
#     61    25  575.33830    9  382  572.54563  575.33830  0.49%   600   10s
# H   93    39                     572.6500200  575.33830  0.47%   468   10s
# H  611   166                     573.4793100  575.33830  0.32%   189   13s
# *  706   217              23     574.3528700  575.33830  0.17%   168   13s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 34
#   Clique: 1
#   MIR: 29
#   StrongCG: 8
#   Flow cover: 13
#   Zero half: 7
#   RLT: 702
#
# Explored 1333 nodes (153835 simplex iterations) in 14.30 seconds (15.76 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 574.353 573.479 572.65 ... 545.852
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.743528700000e+02, best bound 5.743528700000e+02, gap 0.0000%
#
# User-callback calls 3598, time in user-callback 0.00 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-09
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1185G7 @ 3.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3974 rows, 4120 columns and 14964 nonzeros
# Model fingerprint: 0x4531e2a5
# Model has 1634 quadratic objective terms
# Variable types: 0 continuous, 4120 integer (4104 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e-02, 7e+00]
#   QObjective range [3e-02, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective 405.5112000
# Presolve removed 351 rows and 483 columns
# Presolve time: 0.05s
# Presolved: 5067 rows, 5081 columns, 17664 nonzeros
# Variable types: 0 continuous, 5081 integer (5062 binary)
#
# Root relaxation: objective 7.412556e+02, 7221 iterations, 0.50 seconds (0.59 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  741.25560    0 1455  405.51120  741.25560  82.8%     -    0s
# H    0     0                     480.8689800  741.25560  54.1%     -    0s
# H    0     0                     499.8523800  741.25560  48.3%     -    0s
# H    0     0                     502.8524300  741.25560  47.4%     -    1s
#      0     0  623.71481    0 1271  502.85243  623.71481  24.0%     -    1s
#      0     0  623.62679    0 1254  502.85243  623.62679  24.0%     -    2s
# H    0     0                     510.9242900  621.80593  21.7%     -    3s
#      0     0  519.98893    0 1066  510.92429  519.98893  1.77%     -    3s
#      0     0  519.86630    0 1044  510.92429  519.86630  1.75%     -    3s
#      0     0  514.72785    0 1035  510.92429  514.72785  0.74%     -    4s
#      0     0  514.69678    0 1020  510.92429  514.69678  0.74%     -    4s
# H    0     0                     511.0200800  514.69678  0.72%     -    5s
# H    0     0                     512.3639200  514.69678  0.46%     -    5s
# H    0     0                     512.8834200  514.54577  0.32%     -    6s
#      0     0  514.39348    0 1022  512.88342  514.39348  0.29%     -    6s
#      0     0  514.39149    0 1011  512.88342  514.39149  0.29%     -    6s
#      0     2  514.39149    0 1010  512.88342  514.39149  0.29%     -    6s
# H   65    56                     513.3030300  514.39149  0.21%   350    8s
# H   94    73                     513.3030302  514.39149  0.21%   271    8s
# H  130    91                     513.4169700  514.39149  0.19%   232    8s
# H  168   101                     513.5417800  514.39149  0.17%   201    9s
#    280   156  513.57374   23   72  513.54178  514.39149  0.17%   139   10s
# *  405   188              17     513.8916500  514.27044  0.07%   107   10s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 26
#   Clique: 3
#   MIR: 44
#   StrongCG: 5
#   Flow cover: 13
#   Zero half: 67
#   RLT: 643
#   BQP: 2
#
# Explored 735 nodes (69974 simplex iterations) in 10.66 seconds (10.29 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 513.892 513.542 513.417 ... 502.852
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.138916500000e+02, best bound 5.139024098402e+02, gap 0.0021%
#
# User-callback calls 2226, time in user-callback 0.00 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-09
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1185G7 @ 3.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3441 rows, 3605 columns and 12967 nonzeros
# Model fingerprint: 0x376ff501
# Model has 1440 quadratic objective terms
# Variable types: 0 continuous, 3605 integer (3591 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [2e-01, 8e+00]
#   QObjective range [3e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+02]
# Presolve removed 349 rows and 483 columns
# Presolve time: 0.05s
# Presolved: 4342 rows, 4372 columns, 15110 nonzeros
# Variable types: 0 continuous, 4372 integer (4356 binary)
# Found heuristic solution: objective 378.3567800
#
# Root relaxation: objective 7.105131e+02, 5384 iterations, 0.28 seconds (0.31 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  710.51309    0 1166  378.35678  710.51309  87.8%     -    0s
# H    0     0                     431.5353067  710.51309  64.6%     -    0s
# H    0     0                     445.4077683  710.51309  59.5%     -    0s
#      0     0  589.68290    0  929  445.40777  589.68290  32.4%     -    0s
# H    0     0                     459.1098100  589.68290  28.4%     -    0s
# H    0     0                     464.0943583  515.67133  11.1%     -    1s
#      0     0  515.67133    0  832  464.09436  515.67133  11.1%     -    1s
# H    0     0                     464.3763100  515.67133  11.0%     -    1s
#      0     0  515.36377    0  822  464.37631  515.36377  11.0%     -    1s
# H    0     0                     501.6701083  515.36377  2.73%     -    1s
# H    0     0                     508.3600667  515.36377  1.38%     -    1s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 7
#   Clique: 4
#   MIR: 22
#   StrongCG: 6
#   Flow cover: 9
#   Zero half: 24
#   RLT: 444
#   BQP: 1
#
# Explored 1 nodes (8843 simplex iterations) in 1.66 seconds (1.35 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 508.36 501.67 464.376 ... 378.357
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.083600666667e+02, best bound 5.084096622667e+02, gap 0.0098%
#
# User-callback calls 422, time in user-callback 0.01 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-09
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1185G7 @ 3.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2908 rows, 3090 columns and 10970 nonzeros
# Model fingerprint: 0x12f11fa7
# Model has 1222 quadratic objective terms
# Variable types: 0 continuous, 3090 integer (3078 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [4e-01, 8e+00]
#   QObjective range [8e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective 315.4771950
# Presolve removed 347 rows and 483 columns
# Presolve time: 0.03s
# Presolved: 3593 rows, 3639 columns, 12484 nonzeros
# Variable types: 0 continuous, 3639 integer (3626 binary)
#
# Root relaxation: objective 6.270869e+02, 4212 iterations, 0.22 seconds (0.20 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  627.08693    0  924  315.47719  627.08693  98.8%     -    0s
# H    0     0                     383.0372417  627.08693  63.7%     -    0s
# H    0     0                     397.0334900  627.08693  57.9%     -    0s
# H    0     0                     432.4324300  610.49629  41.2%     -    0s
#      0     0  511.70451    0  805  432.43243  511.70451  18.3%     -    0s
# H    0     0                     434.1810983  511.70451  17.9%     -    0s
#      0     0  438.80076    0  719  434.18110  438.80076  1.06%     -    1s
# H    0     0                     437.3768117  438.80076  0.33%     -    1s
#      0     0  438.62265    0  735  437.37681  438.62265  0.28%     -    1s
# H    0     0                     437.5061933  438.22874  0.17%     -    2s
# H    0     0                     438.1498967  438.22874  0.02%     -    2s
#      0     0  438.16861    0  719  438.14990  438.16861  0.00%     -    2s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 3
#   Clique: 2
#   MIR: 22
#   StrongCG: 6
#   Flow cover: 9
#   Zero half: 99
#   RLT: 288
#   BQP: 2
#
# Explored 1 nodes (8511 simplex iterations) in 2.24 seconds (1.34 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 438.15 437.506 437.377 ... 315.477
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.381498966667e+02, best bound 4.381686145455e+02, gap 0.0043%
#
# User-callback calls 568, time in user-callback 0.00 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-09
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1185G7 @ 3.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2375 rows, 2575 columns and 8973 nonzeros
# Model fingerprint: 0x36835385
# Model has 1018 quadratic objective terms
# Variable types: 0 continuous, 2575 integer (2565 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [7e-03, 9e+00]
#   QObjective range [1e-02, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective 279.4110433
# Presolve removed 345 rows and 483 columns
# Presolve time: 0.02s
# Presolved: 2860 rows, 2922 columns, 9906 nonzeros
# Variable types: 0 continuous, 2922 integer (2912 binary)
#
# Root relaxation: objective 5.239337e+02, 4082 iterations, 0.18 seconds (0.20 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  523.93371    0  638  279.41104  523.93371  87.5%     -    0s
# H    0     0                     336.0145317  523.93371  55.9%     -    0s
# H    0     0                     340.0879767  523.93371  54.1%     -    0s
# H    0     0                     340.2876567  523.93371  54.0%     -    0s
# H    0     0                     340.9026467  523.93371  53.7%     -    0s
#      0     0  395.94377    0  624  340.90265  395.94377  16.1%     -    0s
# H    0     0                     341.2396850  395.94377  16.0%     -    0s
# H    0     0                     363.8921783  395.94377  8.81%     -    0s
# H    0     0                     372.4525967  379.76883  1.96%     -    0s
# H    0     0                     372.6848983  379.76883  1.90%     -    0s
#      0     0  372.98165    0  596  372.68490  372.98165  0.08%     -    0s
#      0     0  372.74140    0  587  372.68490  372.74140  0.02%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 3
#   Clique: 5
#   MIR: 23
#   Flow cover: 5
#   Zero half: 127
#   RLT: 173
#   BQP: 1
#
# Explored 1 nodes (6309 simplex iterations) in 1.26 seconds (0.80 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 9: 372.685 372.453 363.892 ... 279.411
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.726848983333e+02, best bound 3.727188282963e+02, gap 0.0091%
#
# User-callback calls 553, time in user-callback 0.00 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-09
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1185G7 @ 3.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1842 rows, 2060 columns and 6976 nonzeros
# Model fingerprint: 0x97011db4
# Model has 814 quadratic objective terms
# Variable types: 0 continuous, 2060 integer (2052 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [4e-01, 9e+00]
#   QObjective range [8e-01, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective 222.3426383
# Presolve removed 665 rows and 804 columns
# Presolve time: 0.03s
# Presolved: 1803 rows, 1882 columns, 6359 nonzeros
# Variable types: 0 continuous, 1882 integer (1875 binary)
# Found heuristic solution: objective 259.1842067
#
# Root relaxation: objective 4.153103e+02, 2900 iterations, 0.10 seconds (0.10 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  415.31035    0  440  259.18421  415.31035  60.2%     -    0s
# H    0     0                     263.1334850  415.31035  57.8%     -    0s
# H    0     0                     265.0147300  415.31035  56.7%     -    0s
# H    0     0                     268.9324833  415.01290  54.3%     -    0s
#      0     0  346.94519    0  441  268.93248  346.94519  29.0%     -    0s
# H    0     0                     269.7812633  346.94519  28.6%     -    0s
# H    0     0                     271.5387283  307.86802  13.4%     -    0s
# H    0     0                     295.9303333  307.86802  4.03%     -    0s
#      0     0  306.58652    0  420  295.93033  306.58652  3.60%     -    0s
#      0     0  305.60431    0  427  295.93033  305.60431  3.27%     -    0s
# H    0     0                     298.5570167  305.60431  2.36%     -    0s
#      0     0  301.68606    0  367  298.55702  301.68606  1.05%     -    0s
#      0     0  301.68546    0  370  298.55702  301.68546  1.05%     -    0s
# H    0     0                     298.9255650  301.68546  0.92%     -    0s
# H    0     0                     298.9287433  301.68546  0.92%     -    0s
# H    0     0                     299.9013167  300.39509  0.16%     -    0s
#      0     0  299.92673    0  374  299.90132  299.92673  0.01%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Clique: 1
#   MIR: 17
#   StrongCG: 3
#   Flow cover: 3
#   Zero half: 176
#   RLT: 86
#   BQP: 1
#
# Explored 1 nodes (4425 simplex iterations) in 0.99 seconds (0.54 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 299.901 298.929 298.926 ... 263.133
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.999013166667e+02, best bound 2.999267333333e+02, gap 0.0085%
#
# User-callback calls 530, time in user-callback 0.00 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-09
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1185G7 @ 3.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1309 rows, 1545 columns and 4979 nonzeros
# Model fingerprint: 0x76fcefb8
# Model has 610 quadratic objective terms
# Variable types: 0 continuous, 1545 integer (1539 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e-01, 9e+00]
#   QObjective range [1e+00, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective 164.2076033
# Presolve removed 1051 rows and 1178 columns
# Presolve time: 0.01s
# Presolved: 488 rows, 597 columns, 1841 nonzeros
# Variable types: 0 continuous, 597 integer (597 binary)
# Found heuristic solution: objective 195.4867783
#
# Root relaxation: objective 2.284352e+02, 445 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  228.43519    0  112  195.48678  228.43519  16.9%     -    0s
# H    0     0                     197.9873433  228.43519  15.4%     -    0s
# H    0     0                     199.7976367  228.43519  14.3%     -    0s
# H    0     0                     206.4412483  228.43519  10.7%     -    0s
#      0     0  206.44125    0  121  206.44125  206.44125  0.00%     -    0s
#
# Cutting planes:
#   MIR: 1
#   Zero half: 10
#   RLT: 2
#
# Explored 1 nodes (498 simplex iterations) in 0.05 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 206.441 199.798 197.987 ... 164.208
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.064412483333e+02, best bound 2.064412483333e+02, gap 0.0000%
#
# User-callback calls 572, time in user-callback 0.00 sec
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-09
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1185G7 @ 3.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 776 rows, 1030 columns and 2982 nonzeros
# Model fingerprint: 0xe17da185
# Model has 406 quadratic objective terms
# Variable types: 0 continuous, 1030 integer (1026 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e-01, 9e+00]
#   QObjective range [1e+00, 2e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+02]
# Presolve removed 1 rows and 103 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible or unbounded
# Best objective -, best bound -, gap -
#
# User-callback calls 36, time in user-callback 0.00 sec
# Result index of attribute MathOptInterface.ObjectiveValue(1) out of bounds. There are currently 0 solution(s) in the model.
#
# Stacktrace:
#   [1] check_result_index_bounds
#     @ C:\Users\Dilan\.julia\packages\MathOptInterface\pgWRA\src\attributes.jl:207 [inlined]
#   [2] get(model::Gurobi.Optimizer, attr::MathOptInterface.ObjectiveValue)
#     @ Gurobi C:\Users\Dilan\.julia\packages\Gurobi\vStLK\src\MOI_wrapper\MOI_wrapper.jl:3120
#   [3] get(b::MathOptInterface.Bridges.LazyBridgeOptimizer{Gurobi.Optimizer}, attr::MathOptInterface.ObjectiveValue)
#     @ MathOptInterface.Bridges C:\Users\Dilan\.julia\packages\MathOptInterface\pgWRA\src\Bridges\bridge_optimizer.jl:1073
#   [4] _get_model_attribute(model::MathOptInterface.Utilities.CachingOptimizer{MathOptInterface.Bridges.LazyBridgeOptimizer{Gurobi.Optimizer}, MathOptInterface.Utilities.UniversalFallback{MathOptInterface.Utilities.Model{Float64}}}, attr::MathOptInterface.ObjectiveValue)
#     @ MathOptInterface.Utilities C:\Users\Dilan\.julia\packages\MathOptInterface\pgWRA\src\Utilities\cachingoptimizer.jl:828
#   [5] get
#     @ C:\Users\Dilan\.julia\packages\MathOptInterface\pgWRA\src\Utilities\cachingoptimizer.jl:876 [inlined]
#   [6] _moi_get_result(model::MathOptInterface.Utilities.CachingOptimizer{MathOptInterface.Bridges.LazyBridgeOptimizer{Gurobi.Optimizer}, MathOptInterface.Utilities.UniversalFallback{MathOptInterface.Utilities.Model{Float64}}}, args::MathOptInterface.ObjectiveValue)
#     @ JuMP C:\Users\Dilan\.julia\packages\JuMP\ptoff\src\optimizer_interface.jl:640
#   [7] get(model::Model, attr::MathOptInterface.ObjectiveValue)
#     @ JuMP C:\Users\Dilan\.julia\packages\JuMP\ptoff\src\optimizer_interface.jl:660
#   [8] objective_value(model::Model; result::Int64)
#     @ JuMP C:\Users\Dilan\.julia\packages\JuMP\ptoff\src\objective.jl:54
#   [9] objective_value
#     @ C:\Users\Dilan\.julia\packages\JuMP\ptoff\src\objective.jl:50 [inlined]
#  [10] solve_fantasy_football_model(; initial_squad::Vector{Int64}, weeks::UnitRange{Int64}, triple_captains_remaining::Float64, bench_boost_remaining::Float64, wildcard_remaining::Float64, freehit_remaining::Float64)
#     @ Main .\In[13]:122
#  [11] top-level scope
#     @ In[21]:8
